# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style="color: rgb(0,53,91);">
# <center><img src="./Imagenes/ITESO_Logo.png" style="width:500px;height:142px;" title="Logo ITESO"></center>
# <font face = "Times New Roman" size = "6"><b><center>Ingenierías ITESO</center></b></font>
# <font face = "Times New Roman" size = "5"><b><center>Programación para Análisis de Datos</center></b></font>
#
# <b><font face = "Times New Roman" size = "4"><center>Tema 5: Redes Neuronales</center></font>
# <font face = "Times New Roman" size = "4"><center>Subtema e: Clasificación de Imágenes</center></font></b>
# <div align="right"><font face = "Times New Roman" size = "2">Dr. Iván Esteban Villalón Turrubiates (villalon@iteso.mx)</font></div>
# </span></div>

# %% [markdown]
# ## CLASIFICACIÓN DE IMÁGENES
#
# ### Descripción del DataSet
#
# **Asirra (Animal Species Image Recognition for Restricting Access)** es un ***Host Integration Server (HIP)*** de **Microsoft** que funciona por medio de consultas a usuarios para identificar fotografías de perros y gatos. Esta tarea suele ser sumamente compleja para un equipo de cómputo, pero estudios han revelado que las personas pueden realizar esta tarea de manera más rápida y precisa.
#
# **Asirra** es único ya que tiene convenios con grandes compañías que hacen su uso, por ejemplo, con [PetFinder](https://www.petfinder.com), el cual es el sitio más grande a nivel mundial enfocado a encontrar hogares para animales. Ellos han proporcionado a **Microsoft** más de tres millones de imágenes de perros y gatos clasificadas totalmente pero de manera manual, esta información se ha recolectado de miles de refugios de animales a lo largo de los Estados Unidos.
#
# <center><img src="./Imagenes/Kaggle_logo.png" style="width:240px;height:86px;" class="center"></center>
#
# Afortunadamente, existe un subgrupo de esa vasta base de datos, la cual está disponible a través de Kaggle [en esta liga](https://www.kaggle.com/c/dogs-vs-cats/data) llamada *Dogs vs. Cats*, con el objetivo de aplicarlo a procesos de investigación y desarrollo.
#
# El DataSet de 812MB contiene 25,000 imágenes de perros y gatos con sus respectivas clasificaciones, esto para realizar el entrenamiento de una red. Adicionalmente contiene 15,000 imágenes para la etapa de prueba.
#
# En el caso de este ejercicio, se han tomado solamente 1,000 imágenes (500 de perros y 500 de gatos) para hacer un DataSet más pequeño y sencillo de entrenar, adicionalmente se cuenta con 101 imágenes de prueba.
#
# **El problema consiste en entrenar una red neuronal en base a datos ya clasificados, para con ello poder prederir el tipo de animal (perro o gato) presente en una imagen. Por lo mismo, se enfoca a solo 2 clases.**
#
# Comenzaremos mostrando de manera aleatoria una imagen de cada tipo, contenidas dentro de los datos de *entrenamiento (train)*. Para ello se empleará la librería **SciKit-Image** (***skimage***) que ya se había empleado en sesiones previas del curso.

# %%
#Importación de librerías
import matplotlib.pyplot as plt
import random
from skimage import io                  

#Definición de los parámetros de los gráficos
plt.rcParams.update({'font.size': 11, 'figure.figsize': (6, 4)}) 

#Cargar y mostrar una imagen aleatoria de un perro desde el DataSet de Entrenamiento
dog_img = io.imread("./Data_DogCat/train/dog.{}.jpg".format(random.randint(0,499)))
plt.imshow(dog_img, origin=None)      
plt.axis('off')
plt.title("Imagen de un Perro del DataSet de Entrenamiento")
plt.show();
print("Dimensiones de la imagen:", dog_img.shape) 

#Cargar y mostrar una imagen aleatoria de un gato desde el DataSet de Entrenamiento
cat_img = io.imread("./Data_DogCat/train/cat.{}.jpg".format(random.randint(0,499)))
plt.imshow(cat_img, origin=None)        
plt.axis('off')
plt.title("Imagen de un Gato del DataSet de Entrenamiento")
plt.show();
print("Dimensiones de la imagen:", cat_img.shape)
# Out:
# Dimensiones de la imagen: (499, 410, 3)
# Dimensiones de la imagen: (399, 500, 3)

# %% [markdown]
# Se tendrán dos categorías de clasificación (*etiquetas o labels*), las cuales son `dog` y `cat`.
#
# Se comenzará preparando un **DataFrame** de **Pandas**, con el objetivo de recolectar las etiquetas de todos los archivos de entrenamiento (500 imágenes para cada etiqueta). El **DataFrame** tendrá los elementos:
#
# * `filename`: Nombre del archivo.
# * `category`: Categoría a la que pertenece el archivo, ya sea `dog` o `cat`.

# %%
#Importación de librerías
import pandas as pd
import os

#Creación del DataFrame
filenames = os.listdir('./Data_DogCat/train')
categories = []

#Asignación de los nombres y categorías desde los archivos de entrenamiento
for filename in filenames:
  category = filename.split('.')[0]
  if category == 'dog':
    categories.append('dog')
  else:
    categories.append('cat')

#Asignación al DataFrame
dog_cat_df = pd.DataFrame({'filename': filenames,'category': categories})
dog_cat_df.head(10)
# Out:
#       filename category
# 0    cat.6.jpg      cat
# 1  dog.211.jpg      dog
# 2  dog.205.jpg      dog
# 3  dog.239.jpg      dog
# 4  cat.239.jpg      cat
# 5  cat.211.jpg      cat
# 6  cat.205.jpg      cat
# 7  dog.365.jpg      dog
# 8  dog.403.jpg      dog
# 9  dog.417.jpg      dog

# %% [markdown]
# A continuación se realizarán algunas operaciones de preparación de los datos. Para ello se empleará la librería **SciKit-Learn**, la cual contiene herramientas simples y eficientes para análisis predictivo de datos.
#
# <center><img src="./Imagenes/scikit.png" style="width:200px;height:108px;" class="center"></center>
#
# La documentación de **SciKit-Learn** se puede encontrar a través [de esta liga](https://scikit-learn.org/stable/).
#
# Los pasos a seguir son:
# 1. Extracción de **DataFrames** de entrenamiento y prueba de manera aleatoria empleando el método `train_test_split()` aplicado al **DataFrame** original.

# %%
#Importación de librerías
from sklearn.model_selection import train_test_split

#Extracción de DataFrames de entrenamiento y prueba
train_df, test_df = train_test_split(dog_cat_df, test_size = 0.2)

#Revisión de los tamaños de los DataFrames
print("\nEl tamaño del DataFrame de entrada es:", dog_cat_df.shape)
print("El tamaño del DataFrame para entrenamiento es:", train_df.shape)
print("El tamaño del DataFrame para prueba es:", test_df.shape)
# Out:
# El tamaño del DataFrame de entrada es: (1000, 2)
# El tamaño del DataFrame para entrenamiento es: (800, 2)
# El tamaño del DataFrame para prueba es: (200, 2)

# %% [markdown]
# Ahora se realiza un preprocesamiento de las imágenes a través de la función `ImageDataGenerator` de **Keras**. Para ello se empleará el método `.flow_from_dataframe()`, el cual permite tomar un **DataFrame** que contiene los nombres de los archivos y sus respectivas categorías de clasificación, y directamente lee las imágenes desde la ubicación especificada y mapeadas con la respectiva categoría.
#
# Para ello, primero se realiza una normalización de las imágenes (proceso normal para ajustar los valores de 0-255 a la escala de 0-1), y posteriormente se aplica el método `.flow_from_dataframe()` para generar los datos de las imágenes para el entrenamiento y para las pruebas de manera independiente:
#
# 1. Se indica el **DataFrame** desde donde se leen los datos.
# 2. Se indica el directorio desde donde se leeran las imágenes.
# 3. Se indica la columna del **DataFrame** que contiene los nombres de archivos con `x_col`.
# 4. Se indica la columna del **DataFrame** que contiene las categorías de cada archivo con `y_col`.
# 5. Se indica el tamaño al que se van a ajustar todas las imágenes con `target_size`.
# 6. Se especifica que las imágenes son arreglos 2-dimensionales de **NumPy** con `class_mode='categorical'`.
# 7. Se especifica el número de lotes (*batch*) a emplear por medio de `batch_size`.
#
# Se puede consultar más información sobre el método `.flow_from_dataframe()` de **Keras** [en esta liga](https://keras.io/preprocessing/image/).

# %%
#Importación de librerías
from keras.preprocessing.image import ImageDataGenerator

#Normalización de las Imágenes
datagen = ImageDataGenerator(rescale=1.0/255.0)

#Generador de Imágenes de Entrenamiento
traingenerator = datagen.flow_from_dataframe(train_df , './Data_DogCat/train', 
                                             x_col = 'filename' , 
                                             y_col = 'category', 
                                             target_size = (224,224),
                                             class_mode='categorical', 
                                             batch_size = 32)

#Generador de Imágenes de Prueba
testgenerator = datagen.flow_from_dataframe( test_df , './Data_DogCat/train',
                                             x_col = 'filename' , 
                                             y_col = 'category', 
                                             target_size = (224,224),
                                             class_mode='categorical', 
                                             batch_size = 32)
# Out:
# 2024-04-17 20:55:48.753726: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 800 validated image filenames belonging to 2 classes.
# Found 200 validated image filenames belonging to 2 classes.

# %% [markdown]
# Se prepara una **Red Neuronal** basada en el modelo secuencial (`Sequential`) de **Keras** a través de la librería **TensorFlow**, el cual consiste en una apilación (*stack*) lineal de capas (*layers*), esto es, se puede crear un modelo secuencial pasando la lista de capas a través del método `.add()`. Como características:
#
# 1. Se emplearán capas del tipo `Conv2D`, `MaxPooling2D`, `Flatten`, `Dense`, `BatchNormalization` y `Dropout`.
# 2. Se emplearán funciones de activación del tipo `relu` y `softmax`.
#
# Las capas (*layers*) de **Keras** disponibles a través de la librería **TensorFlow** se pueden consultar [en esta liga](https://www.tensorflow.org/api_docs/python/tf/keras/layers).
#
# Las funciones de activación disponibles en **TensorFlow** se pueden consultar [en esta liga](https://www.tensorflow.org/api_docs/python/tf/keras/activations).

# %%
#Importación de la Librería TensorFlow
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

#Preparación del Modelo
model = tf.keras.Sequential()

model.add(Conv2D(32, (5,5), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax')) #Son 2 debido a que son solo dos clases (perro o gato)

#Configuración del modelo de entrenamiento
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# Se puede visualizar una representación del modelo de la **Red Neuronal** creada con **TensorFlow**. Para ello se emplea el método `.summary()` aplicado al modelo. Esto es:

# %%
#Visualización de la Red Neuronal
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 220, 220, 32)      2432
#
#  max_pooling2d (MaxPooling2  (None, 110, 110, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 106, 106, 64)      51264
#
#  max_pooling2d_1 (MaxPoolin  (None, 53, 53, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 49, 49, 128)       204928
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 256)       819456
#
#  max_pooling2d_3 (MaxPoolin  (None, 10, 10, 256)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 256)         1638656
#
#  max_pooling2d_4 (MaxPoolin  (None, 3, 3, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 3899970 (14.88 MB)
# Trainable params: 3898946 (14.87 MB)
# Non-trainable params: 1024 (4.00 KB)
# _________________________________________________________________

# %% [markdown]
# Ahora se realiza el entrenamiento por un cierto número de épocas (*epochs*), las cuales son las iteraciones que se realizan. Para ello se emplea el método `.fit()` de **Keras**. Para ello:
#
# * Se proporcionan los datos de entrada de entrenamiento (*traingenerator*).
# * Se define la cantidad de épocas a emplear (`epochs`).
# * Se define la información que se usará para validar a través de `validation_data`.
# * Se define la cantidad de pasos a realizar con `validation_data` a través de `validation_steps`.
# * Se define la cantidad de pasos de cada época por medio de `steps_per_epoch`.
#
# La descripción detallada del método `.fit()` se puede consultar [en esta liga](https://keras.io/models/sequential/).
#
# ***Nota:*** El tiempo de entrenamiento fue de alrededor de 4 horas para las 200 épocas, esto es, un promedio de 72 segundos por época.

# %%
#Entrenamiento del modelo para 200 épocas
history = model.fit(
    traingenerator, 
    epochs = 200,
    validation_data = testgenerator,
    validation_steps= len(testgenerator),
    steps_per_epoch = len(traingenerator))
# Out:
# Epoch 1/200
# 25/25 [==============================] - 44s 2s/step - loss: 0.8947 - accuracy: 0.5450 - val_loss: 7.0268 - val_accuracy: 0.5100
# Epoch 2/200
# 25/25 [==============================] - 62s 3s/step - loss: 0.8466 - accuracy: 0.5475 - val_loss: 1.8789 - val_accuracy: 0.5150
# Epoch 3/200
# 25/25 [==============================] - 61s 2s/step - loss: 0.8339 - accuracy: 0.5600 - val_loss: 0.9852 - val_accuracy: 0.4800
# Epoch 4/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.8167 - accuracy: 0.5238 - val_loss: 3.1500 - val_accuracy: 0.4900
# Epoch 5/200
# 25/25 [==============================] - 79s 3s/step - loss: 0.7333 - accuracy: 0.5575 - val_loss: 0.9788 - val_accuracy: 0.5450
# Epoch 6/200
# 25/25 [==============================] - 99s 4s/step - loss: 0.7153 - accuracy: 0.5713 - val_loss: 1.1495 - val_accuracy: 0.4950
# Epoch 7/200
# 25/25 [==============================] - 86s 3s/step - loss: 0.7246 - accuracy: 0.5700 - val_loss: 0.8176 - val_accuracy: 0.5950
# Epoch 8/200
# 25/25 [==============================] - 83s 3s/step - loss: 0.6990 - accuracy: 0.5875 - val_loss: 0.8762 - val_accuracy: 0.5400
# Epoch 9/200
# 25/25 [==============================] - 86s 3s/step - loss: 0.7028 - accuracy: 0.5663 - val_loss: 0.7049 - val_accuracy: 0.5600
# Epoch 10/200
# 25/25 [==============================] - 77s 3s/step - loss: 0.6773 - accuracy: 0.5650 - val_loss: 0.8416 - val_accuracy: 0.5500
# Epoch 11/200
# 25/25 [==============================] - 82s 3s/step - loss: 0.6783 - accuracy: 0.6000 - val_loss: 0.7340 - val_accuracy: 0.5800
# Epoch 12/200
# 25/25 [==============================] - 73s 3s/step - loss: 0.7091 - accuracy: 0.5700 - val_loss: 0.6715 - val_accuracy: 0.6150
# Epoch 13/200
# 25/25 [==============================] - 76s 3s/step - loss: 0.6660 - accuracy: 0.5775 - val_loss: 1.9381 - val_accuracy: 0.5350
# Epoch 14/200
# 25/25 [==============================] - 74s 3s/step - loss: 0.7122 - accuracy: 0.5863 - val_loss: 0.9489 - val_accuracy: 0.5300
# Epoch 15/200
# 25/25 [==============================] - 72s 3s/step - loss: 0.6979 - accuracy: 0.5763 - val_loss: 0.9710 - val_accuracy: 0.5550
# Epoch 16/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.6904 - accuracy: 0.5487 - val_loss: 0.7122 - val_accuracy: 0.5300
# Epoch 17/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.6694 - accuracy: 0.5987 - val_loss: 0.8324 - val_accuracy: 0.5450
# Epoch 18/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.6675 - accuracy: 0.5725 - val_loss: 0.6753 - val_accuracy: 0.5950
# Epoch 19/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.6529 - accuracy: 0.6012 - val_loss: 0.6795 - val_accuracy: 0.5800
# Epoch 20/200
# 25/25 [==============================] - 87s 4s/step - loss: 0.6707 - accuracy: 0.6050 - val_loss: 0.7533 - val_accuracy: 0.6000
# Epoch 21/200
# 25/25 [==============================] - 76s 3s/step - loss: 0.6587 - accuracy: 0.5975 - val_loss: 0.7021 - val_accuracy: 0.5700
# Epoch 22/200
# 25/25 [==============================] - 77s 3s/step - loss: 0.6693 - accuracy: 0.5813 - val_loss: 0.7534 - val_accuracy: 0.5750
# Epoch 23/200
# 25/25 [==============================] - 77s 3s/step - loss: 0.6589 - accuracy: 0.6175 - val_loss: 0.7031 - val_accuracy: 0.5900
# Epoch 24/200
# 25/25 [==============================] - 77s 3s/step - loss: 0.6563 - accuracy: 0.5975 - val_loss: 0.6913 - val_accuracy: 0.5800
# Epoch 25/200
# 25/25 [==============================] - 79s 3s/step - loss: 0.6675 - accuracy: 0.6075 - val_loss: 0.7020 - val_accuracy: 0.5650
# Epoch 26/200
# 25/25 [==============================] - 75s 3s/step - loss: 0.6501 - accuracy: 0.6250 - val_loss: 0.6788 - val_accuracy: 0.6000
# Epoch 27/200
# 25/25 [==============================] - 75s 3s/step - loss: 0.6343 - accuracy: 0.6150 - val_loss: 0.6799 - val_accuracy: 0.5550
# Epoch 28/200
# 25/25 [==============================] - 71s 3s/step - loss: 0.6293 - accuracy: 0.6250 - val_loss: 0.6823 - val_accuracy: 0.5700
# Epoch 29/200
# 25/25 [==============================] - 72s 3s/step - loss: 0.6535 - accuracy: 0.6025 - val_loss: 0.7041 - val_accuracy: 0.5650
# Epoch 30/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.6070 - accuracy: 0.6600 - val_loss: 0.6760 - val_accuracy: 0.5650
# Epoch 31/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.6140 - accuracy: 0.6413 - val_loss: 0.6891 - val_accuracy: 0.5650
# Epoch 32/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.6433 - accuracy: 0.6112 - val_loss: 0.7430 - val_accuracy: 0.5350
# Epoch 33/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.6331 - accuracy: 0.6112 - val_loss: 0.7044 - val_accuracy: 0.5400
# Epoch 34/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.6362 - accuracy: 0.6175 - val_loss: 0.6760 - val_accuracy: 0.5500
# Epoch 35/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.6330 - accuracy: 0.6175 - val_loss: 0.7134 - val_accuracy: 0.5450
# Epoch 36/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.6230 - accuracy: 0.6687 - val_loss: 0.7076 - val_accuracy: 0.6100
# Epoch 37/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.6099 - accuracy: 0.6425 - val_loss: 0.6861 - val_accuracy: 0.5750
# Epoch 38/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.6077 - accuracy: 0.6662 - val_loss: 0.6869 - val_accuracy: 0.6050
# Epoch 39/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.6059 - accuracy: 0.6475 - val_loss: 0.7246 - val_accuracy: 0.6000
# Epoch 40/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.5783 - accuracy: 0.6875 - val_loss: 0.7118 - val_accuracy: 0.5400
# Epoch 41/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.5826 - accuracy: 0.6787 - val_loss: 0.6945 - val_accuracy: 0.5800
# Epoch 42/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.5763 - accuracy: 0.6850 - val_loss: 0.6718 - val_accuracy: 0.5750
# Epoch 43/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.6512 - accuracy: 0.6125 - val_loss: 0.6814 - val_accuracy: 0.5550
# Epoch 44/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.6216 - accuracy: 0.6612 - val_loss: 1.0734 - val_accuracy: 0.5200
# Epoch 45/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.5939 - accuracy: 0.6837 - val_loss: 0.6854 - val_accuracy: 0.5600
# Epoch 46/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.5839 - accuracy: 0.6875 - val_loss: 0.6776 - val_accuracy: 0.5950
# Epoch 47/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.5597 - accuracy: 0.7000 - val_loss: 0.7204 - val_accuracy: 0.5350
# Epoch 48/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.5693 - accuracy: 0.6812 - val_loss: 0.7730 - val_accuracy: 0.5300
# Epoch 49/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.5803 - accuracy: 0.6862 - val_loss: 0.6473 - val_accuracy: 0.6150
# Epoch 50/200
# 25/25 [==============================] - 71s 3s/step - loss: 0.5581 - accuracy: 0.7188 - val_loss: 0.7990 - val_accuracy: 0.5450
# Epoch 51/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.5513 - accuracy: 0.7200 - val_loss: 0.6819 - val_accuracy: 0.5900
# Epoch 52/200
# 25/25 [==============================] - 71s 3s/step - loss: 0.5076 - accuracy: 0.7475 - val_loss: 1.2015 - val_accuracy: 0.5400
# Epoch 53/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.5021 - accuracy: 0.7362 - val_loss: 0.6358 - val_accuracy: 0.5950
# Epoch 54/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.4775 - accuracy: 0.7588 - val_loss: 0.7570 - val_accuracy: 0.5400
# Epoch 55/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.4537 - accuracy: 0.7700 - val_loss: 0.7434 - val_accuracy: 0.5750
# Epoch 56/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.4134 - accuracy: 0.8087 - val_loss: 0.6792 - val_accuracy: 0.5700
# Epoch 57/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.4399 - accuracy: 0.7725 - val_loss: 0.6662 - val_accuracy: 0.6750
# Epoch 58/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.3570 - accuracy: 0.8450 - val_loss: 0.9158 - val_accuracy: 0.5650
# Epoch 59/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.3167 - accuracy: 0.8600 - val_loss: 1.2055 - val_accuracy: 0.5050
# Epoch 60/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.2763 - accuracy: 0.8888 - val_loss: 0.7839 - val_accuracy: 0.5650
# Epoch 61/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.3228 - accuracy: 0.8587 - val_loss: 0.6766 - val_accuracy: 0.6550
# Epoch 62/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.2782 - accuracy: 0.8888 - val_loss: 0.9014 - val_accuracy: 0.5800
# Epoch 63/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.2390 - accuracy: 0.9062 - val_loss: 0.7991 - val_accuracy: 0.6150
# Epoch 64/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.2134 - accuracy: 0.9200 - val_loss: 0.8539 - val_accuracy: 0.6400
# Epoch 65/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.1132 - accuracy: 0.9613 - val_loss: 0.9065 - val_accuracy: 0.6000
# Epoch 66/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0648 - accuracy: 0.9787 - val_loss: 0.8125 - val_accuracy: 0.6850
# Epoch 67/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0686 - accuracy: 0.9800 - val_loss: 2.1875 - val_accuracy: 0.5550
# Epoch 68/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.2287 - accuracy: 0.9025 - val_loss: 1.0925 - val_accuracy: 0.6550
# Epoch 69/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.3394 - accuracy: 0.8725 - val_loss: 2.2016 - val_accuracy: 0.5650
# Epoch 70/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.5607 - accuracy: 0.7487 - val_loss: 1.3605 - val_accuracy: 0.6050
# Epoch 71/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.3209 - accuracy: 0.8700 - val_loss: 0.7579 - val_accuracy: 0.6450
# Epoch 72/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.1576 - accuracy: 0.9463 - val_loss: 1.1163 - val_accuracy: 0.6200
# Epoch 73/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.0833 - accuracy: 0.9787 - val_loss: 1.4021 - val_accuracy: 0.6250
# Epoch 74/200
# 25/25 [==============================] - 71s 3s/step - loss: 0.0544 - accuracy: 0.9850 - val_loss: 1.1879 - val_accuracy: 0.5950
# Epoch 75/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0491 - accuracy: 0.9862 - val_loss: 1.5273 - val_accuracy: 0.5950
# Epoch 76/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0452 - accuracy: 0.9887 - val_loss: 1.5364 - val_accuracy: 0.5900
# Epoch 77/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.0402 - accuracy: 0.9900 - val_loss: 1.2948 - val_accuracy: 0.6950
# Epoch 78/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0442 - accuracy: 0.9862 - val_loss: 1.8062 - val_accuracy: 0.5950
# Epoch 79/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0321 - accuracy: 0.9925 - val_loss: 1.4697 - val_accuracy: 0.6000
# Epoch 80/200
# 25/25 [==============================] - 71s 3s/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 1.2312 - val_accuracy: 0.6200
# Epoch 81/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0129 - accuracy: 0.9962 - val_loss: 1.4488 - val_accuracy: 0.6100
# Epoch 82/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0071 - accuracy: 0.9987 - val_loss: 1.3919 - val_accuracy: 0.6350
# Epoch 83/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.5320 - val_accuracy: 0.6150
# Epoch 84/200
# 25/25 [==============================] - 88s 4s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.5268 - val_accuracy: 0.6450
# Epoch 85/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.5412 - val_accuracy: 0.6350
# Epoch 86/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.5220 - val_accuracy: 0.6450
# Epoch 87/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.6789 - val_accuracy: 0.6600
# Epoch 88/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.6076 - val_accuracy: 0.6550
# Epoch 89/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.6358 - val_accuracy: 0.6550
# Epoch 90/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.6964 - val_accuracy: 0.6450
# Epoch 91/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.7658 - val_accuracy: 0.6300
# Epoch 92/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.7144 - val_accuracy: 0.6450
# Epoch 93/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.6827 - val_accuracy: 0.6550
# Epoch 94/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.7672 - val_accuracy: 0.6500
# Epoch 95/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.7540 - val_accuracy: 0.6650
# Epoch 96/200
# 25/25 [==============================] - 69s 3s/step - loss: 7.9253e-04 - accuracy: 1.0000 - val_loss: 1.7346 - val_accuracy: 0.6600
# Epoch 97/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.8595 - val_accuracy: 0.6350
# Epoch 98/200
# 25/25 [==============================] - 65s 3s/step - loss: 5.8192e-04 - accuracy: 1.0000 - val_loss: 1.8420 - val_accuracy: 0.6400
# Epoch 99/200
# 25/25 [==============================] - 69s 3s/step - loss: 9.5587e-04 - accuracy: 1.0000 - val_loss: 1.8023 - val_accuracy: 0.6550
# Epoch 100/200
# 25/25 [==============================] - 69s 3s/step - loss: 4.7213e-04 - accuracy: 1.0000 - val_loss: 1.7777 - val_accuracy: 0.6650
# Epoch 101/200
# 25/25 [==============================] - 65s 3s/step - loss: 4.6085e-04 - accuracy: 1.0000 - val_loss: 1.7877 - val_accuracy: 0.6600
# Epoch 102/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.8353 - val_accuracy: 0.6450
# Epoch 103/200
# 25/25 [==============================] - 65s 3s/step - loss: 4.4391e-04 - accuracy: 1.0000 - val_loss: 1.8614 - val_accuracy: 0.6350
# Epoch 104/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.8420 - val_accuracy: 0.6600
# Epoch 105/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.0144 - val_accuracy: 0.6300
# Epoch 106/200
# 25/25 [==============================] - 67s 3s/step - loss: 9.1658e-04 - accuracy: 1.0000 - val_loss: 1.8956 - val_accuracy: 0.6350
# Epoch 107/200
# 25/25 [==============================] - 66s 3s/step - loss: 7.3160e-04 - accuracy: 1.0000 - val_loss: 1.8595 - val_accuracy: 0.6550
# Epoch 108/200
# 25/25 [==============================] - 70s 3s/step - loss: 3.7229e-04 - accuracy: 1.0000 - val_loss: 1.8739 - val_accuracy: 0.6550
# Epoch 109/200
# 25/25 [==============================] - 65s 3s/step - loss: 3.4527e-04 - accuracy: 1.0000 - val_loss: 1.8606 - val_accuracy: 0.6550
# Epoch 110/200
# 25/25 [==============================] - 71s 3s/step - loss: 3.7435e-04 - accuracy: 1.0000 - val_loss: 1.8537 - val_accuracy: 0.6600
# Epoch 111/200
# 25/25 [==============================] - 69s 3s/step - loss: 3.7445e-04 - accuracy: 1.0000 - val_loss: 1.8672 - val_accuracy: 0.6550
# Epoch 112/200
# 25/25 [==============================] - 72s 3s/step - loss: 2.7155e-04 - accuracy: 1.0000 - val_loss: 1.8817 - val_accuracy: 0.6600
# Epoch 113/200
# 25/25 [==============================] - 73s 3s/step - loss: 2.6420e-04 - accuracy: 1.0000 - val_loss: 1.8508 - val_accuracy: 0.6600
# Epoch 114/200
# 25/25 [==============================] - 71s 3s/step - loss: 6.4269e-04 - accuracy: 1.0000 - val_loss: 1.8800 - val_accuracy: 0.6600
# Epoch 115/200
# 25/25 [==============================] - 74s 3s/step - loss: 3.0732e-04 - accuracy: 1.0000 - val_loss: 1.9127 - val_accuracy: 0.6550
# Epoch 116/200
# 25/25 [==============================] - 72s 3s/step - loss: 3.5657e-04 - accuracy: 1.0000 - val_loss: 1.9331 - val_accuracy: 0.6600
# Epoch 117/200
# 25/25 [==============================] - 66s 3s/step - loss: 3.9011e-04 - accuracy: 1.0000 - val_loss: 1.9670 - val_accuracy: 0.6500
# Epoch 118/200
# 25/25 [==============================] - 67s 3s/step - loss: 3.2112e-04 - accuracy: 1.0000 - val_loss: 1.9259 - val_accuracy: 0.6650
# Epoch 119/200
# 25/25 [==============================] - 70s 3s/step - loss: 1.8620e-04 - accuracy: 1.0000 - val_loss: 1.9143 - val_accuracy: 0.6650
# Epoch 120/200
# 25/25 [==============================] - 65s 3s/step - loss: 1.7741e-04 - accuracy: 1.0000 - val_loss: 1.9303 - val_accuracy: 0.6600
# Epoch 121/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.9504 - val_accuracy: 0.6600
# Epoch 122/200
# 25/25 [==============================] - 73s 3s/step - loss: 2.9717e-04 - accuracy: 1.0000 - val_loss: 1.9245 - val_accuracy: 0.6550
# Epoch 123/200
# 25/25 [==============================] - 73s 3s/step - loss: 3.6749e-04 - accuracy: 1.0000 - val_loss: 1.9566 - val_accuracy: 0.6600
# Epoch 124/200
# 25/25 [==============================] - 67s 3s/step - loss: 2.9866e-04 - accuracy: 1.0000 - val_loss: 2.0922 - val_accuracy: 0.6450
# Epoch 125/200
# 25/25 [==============================] - 72s 3s/step - loss: 5.1231e-04 - accuracy: 1.0000 - val_loss: 2.0614 - val_accuracy: 0.6450
# Epoch 126/200
# 25/25 [==============================] - 66s 3s/step - loss: 8.8056e-04 - accuracy: 1.0000 - val_loss: 2.0684 - val_accuracy: 0.6450
# Epoch 127/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.9419 - val_accuracy: 0.6500
# Epoch 128/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.0235 - accuracy: 0.9887 - val_loss: 2.2794 - val_accuracy: 0.6250
# Epoch 129/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.0584 - accuracy: 0.9762 - val_loss: 2.6088 - val_accuracy: 0.6000
# Epoch 130/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0725 - accuracy: 0.9700 - val_loss: 4.1016 - val_accuracy: 0.5600
# Epoch 131/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.1716 - accuracy: 0.9337 - val_loss: 1.8034 - val_accuracy: 0.6700
# Epoch 132/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.1035 - accuracy: 0.9638 - val_loss: 2.5963 - val_accuracy: 0.6050
# Epoch 133/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0596 - accuracy: 0.9787 - val_loss: 1.8779 - val_accuracy: 0.6450
# Epoch 134/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.0397 - accuracy: 0.9862 - val_loss: 1.8260 - val_accuracy: 0.6000
# Epoch 135/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0552 - accuracy: 0.9762 - val_loss: 1.9105 - val_accuracy: 0.6250
# Epoch 136/200
# 25/25 [==============================] - 71s 3s/step - loss: 0.0467 - accuracy: 0.9837 - val_loss: 1.9434 - val_accuracy: 0.6300
# Epoch 137/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0116 - accuracy: 0.9975 - val_loss: 1.7912 - val_accuracy: 0.6550
# Epoch 138/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 2.1833 - val_accuracy: 0.6050
# Epoch 139/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 1.7671 - val_accuracy: 0.6400
# Epoch 140/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.8377 - val_accuracy: 0.6500
# Epoch 141/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.8872 - val_accuracy: 0.6500
# Epoch 142/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 1.9412 - val_accuracy: 0.6400
# Epoch 143/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.0067 - accuracy: 0.9987 - val_loss: 2.0172 - val_accuracy: 0.6450
# Epoch 144/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 2.1746 - val_accuracy: 0.6200
# Epoch 145/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.9140 - val_accuracy: 0.6500
# Epoch 146/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.3026 - val_accuracy: 0.6400
# Epoch 147/200
# 25/25 [==============================] - 68s 3s/step - loss: 7.2034e-04 - accuracy: 1.0000 - val_loss: 2.0361 - val_accuracy: 0.6750
# Epoch 148/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.0130 - val_accuracy: 0.6750
# Epoch 149/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0022 - accuracy: 0.9987 - val_loss: 1.9516 - val_accuracy: 0.6450
# Epoch 150/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 1.9176 - val_accuracy: 0.6500
# Epoch 151/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0068 - accuracy: 0.9962 - val_loss: 2.2179 - val_accuracy: 0.6450
# Epoch 152/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.1482 - val_accuracy: 0.6200
# Epoch 153/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0057 - accuracy: 0.9987 - val_loss: 2.0598 - val_accuracy: 0.6400
# Epoch 154/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.1147 - val_accuracy: 0.6350
# Epoch 155/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 2.0448 - val_accuracy: 0.6450
# Epoch 156/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.0065 - accuracy: 0.9987 - val_loss: 1.9123 - val_accuracy: 0.6550
# Epoch 157/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.9316 - val_accuracy: 0.6500
# Epoch 158/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.9777 - val_accuracy: 0.6500
# Epoch 159/200
# 25/25 [==============================] - 67s 3s/step - loss: 4.8941e-04 - accuracy: 1.0000 - val_loss: 2.0322 - val_accuracy: 0.6550
# Epoch 160/200
# 25/25 [==============================] - 68s 3s/step - loss: 3.6972e-04 - accuracy: 1.0000 - val_loss: 2.0361 - val_accuracy: 0.6500
# Epoch 161/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0114 - accuracy: 0.9950 - val_loss: 2.1376 - val_accuracy: 0.6250
# Epoch 162/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0090 - accuracy: 0.9962 - val_loss: 1.8738 - val_accuracy: 0.6750
# Epoch 163/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.0075 - accuracy: 0.9962 - val_loss: 1.6843 - val_accuracy: 0.6550
# Epoch 164/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 2.0849 - val_accuracy: 0.6450
# Epoch 165/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.9994 - val_accuracy: 0.6550
# Epoch 166/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.0707 - val_accuracy: 0.6600
# Epoch 167/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.0018 - val_accuracy: 0.6800
# Epoch 168/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.1530 - val_accuracy: 0.6500
# Epoch 169/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.1158 - val_accuracy: 0.6550
# Epoch 170/200
# 25/25 [==============================] - 71s 3s/step - loss: 4.4483e-04 - accuracy: 1.0000 - val_loss: 2.0395 - val_accuracy: 0.6600
# Epoch 171/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.9896 - val_accuracy: 0.6700
# Epoch 172/200
# 25/25 [==============================] - 65s 3s/step - loss: 5.3787e-04 - accuracy: 1.0000 - val_loss: 2.0550 - val_accuracy: 0.6700
# Epoch 173/200
# 25/25 [==============================] - 70s 3s/step - loss: 9.3653e-04 - accuracy: 1.0000 - val_loss: 2.1235 - val_accuracy: 0.6450
# Epoch 174/200
# 25/25 [==============================] - 68s 3s/step - loss: 5.3937e-04 - accuracy: 1.0000 - val_loss: 2.1834 - val_accuracy: 0.6550
# Epoch 175/200
# 25/25 [==============================] - 67s 3s/step - loss: 3.5217e-04 - accuracy: 1.0000 - val_loss: 2.1772 - val_accuracy: 0.6500
# Epoch 176/200
# 25/25 [==============================] - 70s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.1587 - val_accuracy: 0.6450
# Epoch 177/200
# 25/25 [==============================] - 67s 3s/step - loss: 7.5050e-04 - accuracy: 1.0000 - val_loss: 2.1971 - val_accuracy: 0.6700
# Epoch 178/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.2067 - val_accuracy: 0.6750
# Epoch 179/200
# 25/25 [==============================] - 68s 3s/step - loss: 4.5690e-04 - accuracy: 1.0000 - val_loss: 2.2017 - val_accuracy: 0.6750
# Epoch 180/200
# 25/25 [==============================] - 68s 3s/step - loss: 2.1462e-04 - accuracy: 1.0000 - val_loss: 2.2441 - val_accuracy: 0.6750
# Epoch 181/200
# 25/25 [==============================] - 67s 3s/step - loss: 1.1967e-04 - accuracy: 1.0000 - val_loss: 2.2428 - val_accuracy: 0.6750
# Epoch 182/200
# 25/25 [==============================] - 69s 3s/step - loss: 1.9102e-04 - accuracy: 1.0000 - val_loss: 2.2452 - val_accuracy: 0.6700
# Epoch 183/200
# 25/25 [==============================] - 66s 3s/step - loss: 3.5397e-04 - accuracy: 1.0000 - val_loss: 2.2735 - val_accuracy: 0.6700
# Epoch 184/200
# 25/25 [==============================] - 71s 3s/step - loss: 2.2267e-04 - accuracy: 1.0000 - val_loss: 2.2862 - val_accuracy: 0.6700
# Epoch 185/200
# 25/25 [==============================] - 67s 3s/step - loss: 5.0098e-05 - accuracy: 1.0000 - val_loss: 2.2835 - val_accuracy: 0.6700
# Epoch 186/200
# 25/25 [==============================] - 71s 3s/step - loss: 2.4173e-04 - accuracy: 1.0000 - val_loss: 2.3017 - val_accuracy: 0.6700
# Epoch 187/200
# 25/25 [==============================] - 65s 3s/step - loss: 5.0377e-04 - accuracy: 1.0000 - val_loss: 2.3248 - val_accuracy: 0.6850
# Epoch 188/200
# 25/25 [==============================] - 70s 3s/step - loss: 8.2326e-05 - accuracy: 1.0000 - val_loss: 2.2990 - val_accuracy: 0.6750
# Epoch 189/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.1417 - val_accuracy: 0.6550
# Epoch 190/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0023 - accuracy: 0.9987 - val_loss: 2.3203 - val_accuracy: 0.6700
# Epoch 191/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0019 - accuracy: 0.9987 - val_loss: 2.8849 - val_accuracy: 0.6400
# Epoch 192/200
# 25/25 [==============================] - 65s 3s/step - loss: 0.0293 - accuracy: 0.9937 - val_loss: 2.4160 - val_accuracy: 0.6350
# Epoch 193/200
# 25/25 [==============================] - 68s 3s/step - loss: 0.1185 - accuracy: 0.9513 - val_loss: 2.5626 - val_accuracy: 0.6500
# Epoch 194/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.1283 - accuracy: 0.9613 - val_loss: 2.3228 - val_accuracy: 0.6400
# Epoch 195/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0703 - accuracy: 0.9775 - val_loss: 2.1089 - val_accuracy: 0.6550
# Epoch 196/200
# 25/25 [==============================] - 67s 3s/step - loss: 0.0275 - accuracy: 0.9887 - val_loss: 2.0876 - val_accuracy: 0.6600
# Epoch 197/200
# 25/25 [==============================] - 66s 3s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.9032 - val_accuracy: 0.6400
# Epoch 198/200
# 25/25 [==============================] - 69s 3s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.8584 - val_accuracy: 0.6550
# Epoch 199/200
# 25/25 [==============================] - 75s 3s/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 1.9506 - val_accuracy: 0.6350
# Epoch 200/200
# 25/25 [==============================] - 72s 3s/step - loss: 0.0179 - accuracy: 0.9925 - val_loss: 2.8454 - val_accuracy: 0.6200

# %% [markdown]
# Ahora se muestra el gráfico del nivel de asertividad (*accuracy*) a través de las épocas (*epoch*) de entenamiento, con lo cual se puede realizar una comparativa de su desempeño.
#
# La documentación de **Keras** recomienda emplear el código mostrado a continuación, el cual puede ser consultado [en esta liga](https://keras.io/visualization/#training-history-visualization).

# %%
#Resumen del entrenamiento por medio de la asertividad (accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Nivel de Certeza del Modelo')
plt.ylabel('Certeza')
plt.xlabel('Épocas')
plt.legend(['Entrenamiento', 'Prueba'], loc='best')
plt.show();

# %% [markdown]
# Ahora se muestra el gráfico del nivel de pérdida (*loss*) a través de las épocas (*epoch*) de entenamiento, con lo cual se puede realizar una comparativa de su desempeño.
#
# La documentación de **Keras** recomienda emplear el código mostrado a continuación, el cual puede ser consultado [en esta liga](https://keras.io/visualization/#training-history-visualization).

# %%
#Resumen del entrenamiento por medio de la pérdida (loss)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Nivel de Pérdida del Modelo')
plt.ylabel('Pérdida')
plt.xlabel('Épocas')
plt.legend(['Entrenamiento', 'Prueba'], loc='best')
plt.show();

# %% [markdown]
# Se generará un **Diccionario** en el cual se contengan las categorías clasificación de las imágenes (en este caso son solamente dos: `cat` y `dog`.

# %%
#Generar un Diccionario con las Categorías de Clasificación de las Imágenes
traingenerator.class_indices
labels = (traingenerator.class_indices)
labels = dict((v,k) for k,v in labels.items())
print("Las categorías de clasificación de las imágenes son:", labels)
# Out:
# Las categorías de clasificación de las imágenes son: {0: 'cat', 1: 'dog'}

# %% [markdown]
# Ahora se define una función de **Python** la cual recibe el modelo entrenado y la ubicación de un archivo de prueba, y entrega la clasificación del contenido de la imágen.

# %%
#Importación de Librerías
import numpy as np
from skimage.transform import resize

#Definir una Función para Pruebas
def test_the_model(model, image_path):
  img = io.imread(image_path)
  
  plt.imshow(img, origin=None)
  plt.axis('off')
  plt.title("Imagen de Prueba")
    
  img = resize(img,(224,224))
  img = np.reshape(img,(1,224,224,3))
  img = img/255.0

  prediction = model.predict(img)
  prediction = np.argmax(prediction)
  
  labels = (traingenerator.class_indices)
  labels = dict((v,k) for k,v in labels.items())
  
  return labels[prediction]

# %% [markdown]
# Para probar el modelo, llamamos a la función `test_the_model` con una imagen de prueba e imprimimos el resultado:

# %%
#Llamado a la Función test_the_model para probar el modelo
print('La categoría para la imagen de prueba es:', test_the_model(model, './Data_DogCat/test/10.jpg'))
# Out:
# 1/1 [==============================] - 0s 147ms/step
# La categoría para la imagen de prueba es: cat

# %% [markdown]
# Ahora, es posible guardar la historia del entrenamiento que se obtuvo con el método `model.fit_generator` en un archivo CSV (alrededor de 16KB), esto puede ser de utilidad para un análisis posterior de los datos:

# %%
#Guardar la Historia del Entrenamiento en formato CSV
history_df = pd.DataFrame(history.history) 
with open('./Data_DogCat/history/history.csv', mode='w') as f:
    history_df.to_csv(f)

# %% [markdown]
# De igual manera, es posible guardar el modelo a traves de la función `model.save`, la cual guarda la arquitectura del modelo, sus pesos, y la configuración de entrenamiento en un solo archivo. Esto permite exportar un modelo para que pueda ser usado sin acceso al código original. Debido a que el estado de optimización también es recuperado, puede continuarse un proceso de entrenamiento desde donde se dejó.
#
# El modelo completo puede ser guardado en distintos formatos (`SavedModel` y `HDF5`). Para **TensorFlow**, el formato `SavedModel` es el predeterminado a través de la extensión `TF2`. Sin embargo, el modelo puede ser guardado también en un formato `HDF5` (alrededor de 45MB).
#
# La descripción detallada de la función `model.save` se puede encontrar [en esta liga](https://www.tensorflow.org/tutorials/keras/save_and_load).

# %%
#Warnings OFF
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

#Guardado del Modelo
model.save('./Data_DogCat/model')
# Out:
# INFO:tensorflow:Assets written to: ./Data_DogCat/model/assets
# INFO:tensorflow:Assets written to: ./Data_DogCat/model/assets

# %% [markdown]
# Ahora, se puede cargar ese modelo guardado como un nuevo modelo empleando el método `.load_model()` de **Keras** a través de la librería de **TensorFlow** de la siguiente manera:

# %%
#Cargar el Modelo
new_model = tf.keras.models.load_model('./Data_DogCat/model')

# %% [markdown]
# Para probarlo, volvemos a invocar la función `test_the_model` pero con el nuevo modelo que se ha cargado:

# %%
#Llamado a la Función test_the_model para probar el modelo
print('La categoría para la imagen de prueba es:', test_the_model(new_model, './Imagenes/Lily.jpg'))
# Out:
# 1/1 [==============================] - 0s 109ms/step
# La categoría para la imagen de prueba es: cat

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>.: Fin del Tema :.</b>
# </div>
