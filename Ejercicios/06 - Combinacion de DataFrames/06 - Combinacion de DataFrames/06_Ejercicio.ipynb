# %% [markdown]
# <div class="alert alert-block alert-warning">
# <span style="color: rgb(0,53,91);">
# <center><img src="./Imagenes/ITESO_Logo.png" style="width:500px;height:142px;" title="Logo ITESO"></center>
# <font face = "Times New Roman" size = "6"><b><center>Ingenierías ITESO</center></b></font>
# <font face = "Times New Roman" size = "5"><b><center>Programación para Análisis de Datos</center></b></font>
# <font face = "Times New Roman" size = "5"><center>Ejercicio 6: Combinación de DataFrames de Pandas</center></font></b>
# <div align="right"><font face = "Times New Roman" size = "2">Dr. Iván Esteban Villalón Turrubiates (villalon@iteso.mx)</font></div>
# </span></div>

# %% [markdown]
# #### Nombre del Alumno: Santiago Nuñez Perez
# #### Matrícula: 761552

# %% [markdown]
# #### Instrucciones:
# Por favor, revisa cuidadosamente las siguientes instrucciones:
#
# * Realiza este ejercicio de manera individual.
# * Escribe tu nombre completo y matrícula en la celda correspondiente.
# * Lee cuidadosamente cada uno de los ejercicios y realiza las acciones solicitadas.
# * Coloca tu código ejecutable en las celdas debajo de la explicación de cada reactivo.
# * Una vez terminado, sube en CANVAS sólamente el archivo `.ipynb` en la liga correspondiente.

# %% [markdown]
# #### Explicación:
# Se cuenta con dos grupos de datos que proporcionan información climática, los cuales están en dos archivos `.CSV` donde cada uno de ellos contienen información parcial sobre el clima:
#
# Para el **DataFrame** `Clima_T_H.csv`, los encabezados de las columnas de información son:
#
# 1. **Fecha**: La fecha en la que se realizó la medición.
# 2. **Temperatura**: El valor de la medición de temperatura.
# 3. **Humedad**: El valor de la medición de humedad.
#
# Para el **DataFrame** `Clima_V_P.csv`, los encabezados de las columnas de información son:
#
# 1. **Fecha**: La fecha en la que se realizó la medición.
# 2. **Velocidad_Viento**: El valor de la medición de la velocidad del viento.
# 3. **Presión**: El valor de la medición de la presión.
#
# Para este ejercicio, se deben realizar el proceso de análisis por medio de los reactivos descritos a continuación, donde cada uno tiene un valor de **5 CRÉDITOS**, los cuales se agregarán al total acumulado de cada uno de los alumnos del curso.

# %% [markdown]
# **1.** Cargar las librerías **Pandas** y **Matplotlib**. Posteriormente, crear dos **DataFrames** donde se inserte el contenido de cada una de las bases de datos de este ejercicio, mostrando el contenido de los **DataFrames** a través de la función `display()`.

# %%
# Código del Reactivo 1
import pandas as pd
import matplotlib as plt

th_df = pd.read_csv('./Datos/Clima_T_H.csv')
vp_df = pd.read_csv('./Datos/Clima_V_P.csv')
print(display(th_df))
print(display(vp_df))
# Out:
#          Fecha  Temperatura    Humedad
# 0   2017-01-01    15.913043  85.869565
# 1   2017-01-02    18.500000  77.222222
# 2   2017-01-03    17.111111  81.888889
# 3   2017-01-04    18.700000  70.050000
# 4   2017-01-05    18.388889  74.944444
# ..         ...          ...        ...
# 84  2017-04-06    31.222222  26.000000
# 85  2017-04-07    27.000000  29.875000
# 86  2017-04-08    25.625000  29.375000
# 87  2017-04-09    27.125000  21.125000
# 88  2017-04-10    27.857143  19.428571
#
# [89 rows x 3 columns]
# None
#          Fecha  Velocidad_Viento      Presión
# 0   2017-01-01          2.743478    59.000000
# 1   2017-01-02          2.894444  1018.277778
# 2   2017-01-03          4.016667  1018.333333
# 3   2017-01-04          4.545000  1015.700000
# 4   2017-01-05          3.300000  1014.333333
# ..         ...               ...          ...
# 84  2017-04-06         13.577778  1002.888889
# 85  2017-04-07          4.650000  1007.375000
# 86  2017-04-08          8.337500  1010.375000
# 87  2017-04-09         14.125000  1010.625000
# 88  2017-04-10         19.314286  1008.571429
#
# [89 rows x 3 columns]
# None

# %% [markdown]
# **2.** Realizar la combinación de los **DataFrames** empleando el método `.merge()` con los parámetros más adecuados para que se tenga la menor cantidad de pérdida de información, y mostrar el **DataFrame** resultante a través de la función `display()`.

# %%
# Código del Reactivo 2
comb_df = pd.merge(th_df, vp_df, on = 'Fecha')

print("La combinación de los DataFrames es:")
comb_df
# Out:
# La combinación de los DataFrames es:
#          Fecha  Temperatura    Humedad  Velocidad_Viento      Presión
# 0   2017-01-01    15.913043  85.869565          2.743478    59.000000
# 1   2017-01-02    18.500000  77.222222          2.894444  1018.277778
# 2   2017-01-03    17.111111  81.888889          4.016667  1018.333333
# 3   2017-01-04    18.700000  70.050000          4.545000  1015.700000
# 4   2017-01-05    18.388889  74.944444          3.300000  1014.333333
# ..         ...          ...        ...               ...          ...
# 73  2017-04-06    31.222222  26.000000         13.577778  1002.888889
# 74  2017-04-07    27.000000  29.875000          4.650000  1007.375000
# 75  2017-04-08    25.625000  29.375000          8.337500  1010.375000
# 76  2017-04-09    27.125000  21.125000         14.125000  1010.625000
# 77  2017-04-10    27.857143  19.428571         19.314286  1008.571429
#
# [78 rows x 5 columns]

# %% [markdown]
# **3.** Realizar el llenado de los ***valores nulos*** en el **DataFrame** resultante y mostrarlo a través de la función `display()`.
#
# ***Nota:*** Hay dos alternativas para ello:
# 1. Usar el método `.merge_ordered()` para combinar los **DataFrames** y llenar los **valores nulos**.
# 2. Después de la combinación de los **DataFrames**, emplear el método `.fillna()` para llenar los **valores nulos**.

# %%
# Código del Reactivo 3
comb_df = pd.merge_ordered(th_df, vp_df, 
                           how = 'outer', 
                           fill_method = 'ffill',
                           on = 'Fecha')

#Impresión de los Resultados
print("La combinación de los DataFrames es:")
comb_df
# Out:
# La combinación de los DataFrames es:
#          Fecha  Temperatura    Humedad  Velocidad_Viento      Presión
# 0   2017-01-01    15.913043  85.869565          2.743478    59.000000
# 1   2017-01-02    18.500000  77.222222          2.894444  1018.277778
# 2   2017-01-03    17.111111  81.888889          4.016667  1018.333333
# 3   2017-01-04    18.700000  70.050000          4.545000  1015.700000
# 4   2017-01-05    18.388889  74.944444          3.300000  1014.333333
# ..         ...          ...        ...               ...          ...
# 95  2017-04-06    31.222222  26.000000         13.577778  1002.888889
# 96  2017-04-07    27.000000  29.875000          4.650000  1007.375000
# 97  2017-04-08    25.625000  29.375000          8.337500  1010.375000
# 98  2017-04-09    27.125000  21.125000         14.125000  1010.625000
# 99  2017-04-10    27.857143  19.428571         19.314286  1008.571429
#
# [100 rows x 5 columns]

# %% [markdown]
# **4.** Convertir la columna `Fecha` al formato de **Series de Tiempo** y definirla como el **Indice**, mostrando el **DataFrame** resultante a través de la función `display()`.

# %%
# Código del Reactivo 4
from datetime import datetime
comb_df['Fecha'] = pd.to_datetime(comb_df['Fecha'])
comb_df.set_index('Fecha', inplace = True) 
print(display(comb_df))
# Out:
#             Temperatura    Humedad  Velocidad_Viento      Presión
# Fecha
# 2017-01-01    15.913043  85.869565          2.743478    59.000000
# 2017-01-02    18.500000  77.222222          2.894444  1018.277778
# 2017-01-03    17.111111  81.888889          4.016667  1018.333333
# 2017-01-04    18.700000  70.050000          4.545000  1015.700000
# 2017-01-05    18.388889  74.944444          3.300000  1014.333333
# ...                 ...        ...               ...          ...
# 2017-04-06    31.222222  26.000000         13.577778  1002.888889
# 2017-04-07    27.000000  29.875000          4.650000  1007.375000
# 2017-04-08    25.625000  29.375000          8.337500  1010.375000
# 2017-04-09    27.125000  21.125000         14.125000  1010.625000
# 2017-04-10    27.857143  19.428571         19.314286  1008.571429
#
# [100 rows x 4 columns]
# None

# %% [markdown]
# **5.** Realizar una gráfica que muestre el comportamiento de las 4 variables (temperatura, humedad, velocidad del viento y presión) con sus respectivas etiquetas.

# %%
# Código del Reactivo 5
plt.plot(comb_df['Temperatura'], color = 'red', label = 'Temperatura en C°')
plt.plot(comb_df['Humedad'], color = 'skyblue', label = '% de Humedad')
plt.plot(comb_df['Velocidad_Viento'], color = 'm', label = 'Velocidad del viento en km/h')
plt.title('Datos del DataFrame')
plt.legend(loc='best')
plt.xlabel('Fecha')
plt.ylabel('Valores')
plt.xticks(rotation=0)
plt.show()

plt.plot(comb_df['Presión'], color = 'navy', label = 'Presión bar')
plt.title('Datos de Presión')
plt.legend(loc='best')
plt.xlabel('Fecha')
plt.ylabel('Valores')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>.: Fin del Ejercicio 6 :.</b>
# </div>
